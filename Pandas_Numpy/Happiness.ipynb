# %%
import pandas as pd

# %%
happiness2015 = pd.read_csv("World_Happiness_2015.csv")
happiness2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
happiness2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
happiness2015['Happiness Score'].plot(kind='barh', title='Happiness Scores', ylim=(0,10))
# Out:
# <AxesSubplot:title={'center':'Happiness Scores'}>

# %%
happiness2015['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
so_asia = happiness2015[happiness2015['Region'] == 'Southern Asia']
so_asia.plot(x='Country', y='Happiness Score', kind='barh', title='Southern Asia Happiness Scores', xlim=(0,10))
# Out:
# <AxesSubplot:title={'center':'Southern Asia Happiness Scores'}, ylabel='Country'>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

so_asia.plot(x='Country',y='Happiness Score',kind='barh',title='Southern Asia Region', xlim=(0,10))
# Out:
# <AxesSubplot:title={'center':'Southern Asia Region'}, ylabel='Country'>

# %%
regions = happiness2015.groupby(['Region'])
avrg = regions['Happiness Score'].mean()
#avrg['Happiness Score']
avrg
# Out:
# Region
# Australia and New Zealand          7.285000
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Middle East and Northern Africa    5.406900
# North America                      7.273000
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.202800
# Western Europe                     6.689619
# Name: Happiness Score, dtype: float64

# %%
happiness2015['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
aus_nz = regions.get_group('Australia and New Zealand')

# %%
aus_nz
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 8         0.03371                   1.25018  1.31967
# 9         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  Dystopia Residual
# 8     0.47501            2.26425
# 9     0.43562            2.26646

# %%
happiness2015.iloc[8:10]
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 8         0.03371                   1.25018  1.31967
# 9         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  Dystopia Residual
# 8     0.47501            2.26425
# 9     0.43562            2.26646

# %%
happiness2015.iloc[[4,15]]
# Out:
#    Country                       Region  Happiness Rank  Happiness Score  \
# 4   Canada                North America               5            7.427
# 15  Brazil  Latin America and Caribbean              16            6.983
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 4          0.03553                   1.32629  1.32261
# 15         0.04076                   0.98124  1.23287
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 4                    0.90563  0.63297                        0.32957
# 15                   0.69702  0.49049                        0.17521
#
#     Generosity  Dystopia Residual
# 4      0.45811            2.45176
# 15     0.14574            3.26001

# %%
import numpy as np

regions = happiness2015.groupby(['Region'])
happy_mean_max = regions['Happiness Score'].agg([np.mean,np.max])

happy_mean_max
# Out:
#                                      mean   amax
# Region
# Australia and New Zealand        7.285000  7.286
# Central and Eastern Europe       5.332931  6.505
# Eastern Asia                     5.626167  6.298
# Latin America and Caribbean      6.144682  7.226
# Middle East and Northern Africa  5.406900  7.278
# North America                    7.273000  7.427
# Southeastern Asia                5.317444  6.798
# Southern Asia                    4.580857  5.253
# Sub-Saharan Africa               4.202800  5.477
# Western Europe                   6.689619  7.587

# %%
import numpy as np
grouped = happiness2015.groupby('Region')['Happiness Score','Region'] 

happy_family_stats = grouped.agg([np.min, np.max, np.mean])
happy_family_stats
# Out:
# C:\Users\nvkar\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                 Happiness Score
#                                            amin   amax      mean
# Region
# Australia and New Zealand                 7.284  7.286  7.285000
# Central and Eastern Europe                4.218  6.505  5.332931
# Eastern Asia                              4.874  6.298  5.626167
# Latin America and Caribbean               4.518  7.226  6.144682
# Middle East and Northern Africa           3.006  7.278  5.406900
# North America                             7.119  7.427  7.273000
# Southeastern Asia                         3.819  6.798  5.317444
# Southern Asia                             3.575  5.253  4.580857
# Sub-Saharan Africa                        2.839  5.477  4.202800
# Western Europe                            4.857  7.587  6.689619

# %%
#Pivot table
pv_happy_family_stats = happiness2015.pivot_table(values=['Happiness Score','Family'], index='Region',aggfunc=[np.min, np.max, np.mean], margins=True)
pv_happy_family_stats
# Out:
#                                     amin                     amax  \
#                                   Family Happiness Score   Family
# Region
# Australia and New Zealand        1.30923           7.284  1.31967
# Central and Eastern Europe       0.38562           4.218  1.34043
# Eastern Asia                     0.94675           4.874  1.30060
# Latin America and Caribbean      0.74302           4.518  1.30477
# Middle East and Northern Africa  0.47489           3.006  1.22393
# North America                    1.24711           7.119  1.32261
# Southeastern Asia                0.62736           3.819  1.26504
# Southern Asia                    0.30285           3.575  1.10395
# Sub-Saharan Africa               0.00000           2.839  1.18468
# Western Europe                   0.89318           4.857  1.40223
# All                              0.00000           2.839  1.40223
#
#                                                      mean
# ...

# %% [markdown]
# ## Databases combination

# %%
happiness2015 = pd.read_csv("World_Happiness_2015.csv")

happiness2016 = pd.read_csv("World_Happiness_2016.csv")

happiness2017 = pd.read_csv("World_Happiness_2017.csv")

happiness2015['Year'] = 2015
happiness2016['Year'] = 2016
happiness2017['Year'] = 2017

# %%
head_2015 = happiness2015[['Country','Happiness Score', 'Year']].head(4)
head_2016 = happiness2016[['Country','Happiness Score', 'Year']].head(3)

# %%
head_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015

# %%
head_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016

# %% [markdown]
# ### Function pd.concat([df1,df2])

# %%
#Two types combination:
#   1.Stacked: tail to head (axis = 0)
#   2.Side by side (axis = 1)

# %%
concat_axis0 = pd.concat([head_2015,head_2016], axis=0)
concat_axis0
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016

# %%
concat_axis1 = pd.concat([head_2015,head_2016], axis=1)
concat_axis1
# Out:
#        Country  Happiness Score  Year      Country  Happiness Score    Year
# 0  Switzerland            7.587  2015      Denmark            7.526  2016.0
# 1      Iceland            7.561  2015  Switzerland            7.509  2016.0
# 2      Denmark            7.527  2015      Iceland            7.501  2016.0
# 3       Norway            7.522  2015          NaN              NaN     NaN

# %%
#Number of rows
question1 = concat_axis0.shape[0]
question2 = concat_axis1.shape[0]

# %%
head_2015 = happiness2015[['Year','Country','Happiness Score', 'Standard Error']].head(4)
head_2016 = happiness2016[['Country','Happiness Score', 'Year']].head(3)
